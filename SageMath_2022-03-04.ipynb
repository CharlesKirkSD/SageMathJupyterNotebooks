# %%
circle((1,0),1,rgbcolor=(0,0,1),fill=true)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
1 + 1
# Out:
# 2

# %%
from sage.misc.html import MathJax
mj = MathJax()
var('z')
# Out:
# z

# %%
mj(z^12)
# Out:
# <html><script type="math/tex; mode=display">\newcommand{\Bold}[1]{\mathbf{#1}}z^{12}</script></html>

# %%
plot(x^2,(x,-12,12))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(sin(x^2))
# Out:
# sin(x^2)

# %%
show(LatexExpr(sin(x^2)))
# Out:
# sin(x^2)
