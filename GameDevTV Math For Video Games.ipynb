# %%
plot((3^x),(x,0,8),scale = 'linear', base = 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
log(64)/log(2)
# Out:
# 6

# %% [markdown]
# *Italics*

# %% [markdown]
# $f_{c}(x) = z^{2} + c$

# %% [markdown]
# $c = m - b * t$

# %% [markdown]
# $(30 x 5) - 10n >= 100$

# %% [markdown]
# $150 >= 100 + 10n$

# %% [markdown]
# $15 <= 10 + n$

# %% [markdown]
# $5 >= n$

# %% [markdown]
# $n <= 5$

# %%
t = var('t')
maxFuel = 150
b = 2
plot((maxFuel - b * t),(t,0,75),xmin=-100, xmax=100,ymin=0,ymax=200) # xmin and xmax do not have any effect
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f = var('f') # f is the number of pickups of coins valued at 5
t = var('t') # t is the number of pickups of coins valued at 3
a = f + t == 15 # 15 is the number of pickups in level 1
b = 5*f + 3*t == 55
p1 = implicit_plot(a, (t, 0, 15), (f, 0,15), rgbcolor=(1,0,0))
p2 = implicit_plot(b, (t, 0, 19), (f, 0,11), rgbcolor=(0,0,1))
show(p1 + p2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
y = var('y')
a = 2*x  + 4 == y
b = 2*x + y == 4
p1 = implicit_plot(a, (x, -5, 5), (y, 0, 6), rgbcolor=(1,0,0))
p2 = implicit_plot(b, (x, -5, 5), (y, 0, 6), rgbcolor=(0,0,1))
show(p1 + p2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
a = 2
b = 2
c = -5
eq1 = a * x^2 + 2 * x + c
p1 = plot(eq1(x), (x, -4, 4), rgbcolor=(1,0,0))
show(p1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# *Parabola Intercepts (1,0) (5,0), Vertex (3,3)*

# %% [markdown]
# $y = a(x - p)(x - q)\\
# y = a(x - 1)(x - 5) = 0\\
# 3 = a(3 - 1)(3 -5)\\
# 3 = -4a\\
# a = -3/4$

# %% [markdown]
# *Parabola Intercepts (2,0) (8,0), Vertex (5,3)*

# %% [markdown]
# $\text{Solve for the Intercept Points where y = 0}\\
# y = a(x - p)(x - q)\\
# y = a(2 - p)(8 - p) = 0\\
# p = 2, q = 8\\
# \text{Solve for the Vertex (5,3)}\\
# 3 = a(5 - 2)(5 - 8)\\
# 3 = -9a\\
# a = -1/3\\
# y = -1/3(x -2)(x - 8)$

# %% [markdown]
# $y = -1/3(x - 2)(x - 8)\\
# -3y = x^2 -10x + 16\\
# y = -1/3x^2 +10/3x -16/3$

# %% [markdown]
# *Vertex Form<BR>
# Intercept Points: (1,0) (5,0), Vertex Point: (3,2)<BR>
# General Form:*

# %% [markdown]
# $y = a(x - h)^2 + k$

# %% [markdown]
# *Where k is the height of the Vertex, in this case 2.*

# %% [markdown]
# $y = -1/2(x - 3)^2 + 2\\
# y = -1/2(x - 3)(x -3) +2\\
# y = -1/2x^2 + 3x -5/2$

# %% [markdown]
# *Quadratic Equation : Vertex Form*

# %% [markdown]
# $\textrm{S02_T39 : Challenge}\\
# \textrm{Quadratic Equation : Vertex Form (Squared Form)}\\
# y = a(x - h)^2 + k \text{ Generalized form}\\
# \textrm{ }\\
# \textrm{Intercept Points: (2,0) (8,0)}\\
# \textrm{Vertex Point: (5,3)}\\
# \textrm{Equation in Intercept Form}\\
# y = -1/3(x - 2)(x - 9)\\
# \textrm{Solution}\\
# \text{ }\\
# y = -1/3(x - 5)^2 + 3
# \text{ }\\
# \text{In quadratic form}\\
# y = -1/3(x^2 - 10x + 25) + 3\\
# y = -1/3x^2 + 10/3x -25/3 + 3\\
# y = -1/3x^2 + 10/3x - 16/3$

# %% [markdown]
# $\textrm{S02_T41 : Challenge}\\
# \textrm{Volcanos at Intercept Points (2,0), (8,0)}\\
# \textrm{Convert the Quadratic form to Vertex form}\\
# y = -1/3x^2 + 10/3x - 16/3\\
# -3y = x^2 +10x -16\\
# -3y = (x - 5)^2 -25 +16\\
# y = -1/3(x -5)^2 + 3
# \textrm{ }\\
# \textrm{Check}\\
# y = -1/3(x -5)^2 + 3
# -3y = x^2 - 10x +3 +25 -9\\
# y = -1/3x^2 -10/3x -16/3\\
# $
